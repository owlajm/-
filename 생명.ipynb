# %% [markdown]
# <a href="https://colab.research.google.com/github/owlajm/-/blob/main/%EC%83%9D%EB%AA%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# 정답들이ㅣㅣㅣ야
categories = ["생물", "비생물", "바이러스"]
answer = random.choice(categories)  # 컴퓨터가 정답 선택

# ㅁ오오오ㅗ오든 질문
questions = [
    "물질 대사를 하나요?",
    "자극과 반응을 하나요?",
    "항상성 유지를 하나요?",
    "생식과 유전을 하나요?",
    "발생과 성장을 하나요?",
    "적응과 진화를 하나요?",
    "핵을 가지고 있나요?",
    "빛에 의해 에너지를 변화시킬 수 있나요?",
    "복제라는 개념을 적용할 수 있나요?",
    "다른 것과 상호작용을 하나요?",
    "온도 변화에 영향을 받나요?",
    "물과 상호작용을 하나요?",
    "외부 환경에 따라 형태가 변할 수 있나요?",
    "특정 조건에서 활동을 멈출 수 있나요?",
    "시간의 흐름에 따라 변화할 수 있나요?",
    "인간에게 유익하거나 해로운 영향을 줄 수 있나요?",
    "관찰하기 위해 특수 도구가 필요한가요?",
    "특정 에너지원이 필요하다고 볼 수 있나요?",
    "자연계에서 발견되나요?",
    "과학적 연구의 대상이 될 수 있나요?",
    "말을 할 수 있나요?",
    "스스로 도구를 만들 수 있나요?",
    "운동 에너지를 생성하나요?",
    "날씨를 예측할 수 있나요?",
    "전기를 생산하나요?",
    "스스로 빛을 발하나요?",
    "사람이 직접 제어해야 하나요?",
    "인간이 타고 이동할 수 있나요?",
    "음악을 들을 수 있나요?",
    "기계를 조작할 수 있나요?",
]

# 질문 순서 외우지 마!
random.shuffle(questions)

# 질문-답변 끼리끼리
answers = {
    "물질 대사를 하나요?": {"생물": "예", "비생물": "아니오", "바이러스": "아니오"},
    "자극과 반응을 하나요?": {"생물": "예", "비생물": "아니오", "바이러스": "모르겠음"},
    "항상성 유지를 하나요?": {"생물": "예", "비생물": "아니오", "바이러스": "아니오"},
    "생식과 유전을 하나요?": {"생물": "예", "비생물": "아니오", "바이러스": "예"},
    "발생과 성장을 하나요?": {"생물": "예", "비생물": "아니오", "바이러스": "아니오"},
    "적응과 진화를 하나요?": {"생물": "예", "비생물": "아니오", "바이러스": "예"},
    "핵을 가지고 있나요?": {"생물": "예", "비생물": "아니오", "바이러스": "아니오"},
    "빛에 의해 에너지를 변화시킬 수 있나요?": {"생물": "예", "비생물": "예", "바이러스": "아니오"},
    "복제라는 개념을 적용할 수 있나요?": {"생물": "예", "비생물": "아니오", "바이러스": "예"},
    "다른 것과 상호작용을 하나요?": {"생물": "예", "비생물": "예", "바이러스": "모르겠음"},
    "온도 변화에 영향을 받나요?": {"생물": "예", "비생물": "예", "바이러스": "예"},
    "물과 상호작용을 하나요?": {"생물": "예", "비생물": "예", "바이러스": "예"},
    "외부 환경에 따라 형태가 변할 수 있나요?": {"생물": "예", "비생물": "예", "바이러스": "모르겠음"},
    "특정 조건에서 활동을 멈출 수 있나요?": {"생물": "예", "비생물": "예", "바이러스": "예"},
    "시간의 흐름에 따라 변화할 수 있나요?": {"생물": "예", "비생물": "모르겠음", "바이러스": "모르겠음"},
    "인간에게 유익하거나 해로운 영향을 줄 수 있나요?": {"생물": "예", "비생물": "예", "바이러스": "예"},
    "관찰하기 위해 특수 도구가 필요한가요?": {"생물": "모르겠음", "비생물": "모르겠음", "바이러스": "모르겠음"},
    "특정 에너지원이 필요하다고 볼 수 있나요?": {"생물": "예", "비생물": "모르겠음", "바이러스": "예"},
    "자연계에서 발견되나요?": {"생물": "예", "비생물": "예", "바이러스": "예"},
    "과학적 연구의 대상이 될 수 있나요?": {"생물": "예", "비생물": "예", "바이러스": "예"},
    "말을 할 수 있나요?": {"생물": "아니오", "비생물": "아니오", "바이러스": "아니오"},
    "스스로 도구를 만들 수 있나요?": {"생물": "아니오", "비생물": "아니오", "바이러스": "아니오"},
    "운동 에너지를 생성하나요?": {"생물": "모르겠음", "비생물": "모르겠음", "바이러스": "모르겠음"},
    "날씨를 예측할 수 있나요?": {"생물": "아니오", "비생물": "아니오", "바이러스": "아니오"},
    "전기를 생산하나요?": {"생물": "아니오", "비생물": "예", "바이러스": "아니오"},
    "스스로 빛을 발하나요?": {"생물": "아니오", "비생물": "아니오", "바이러스": "아니오"},
    "사람이 직접 제어해야 하나요?": {"생물": "아니오", "비생물": "예", "바이러스": "아니오"},
    "인간이 타고 이동할 수 있나요?": {"생물": "아니오", "비생물": "예", "바이러스": "아니오"},
    "음악을 들을 수 있나요?": {"생물": "아니오", "비생물": "아니오", "바이러스": "아니오"},
    "기계를 조작할 수 있나요?": {"생물": "아니오", "비생물": "예", "바이러스": "아니오"},
}

# 이렇게 하면 돼
print("컴퓨터가 '생물', '비생물', '바이러스' 중 하나를 선택했습니다.")
print("다음은 질문 예시입니다 (랜덤 순서):")
for q in questions:
    print(f"- {q}")
print("\n이 질문을 참고하여 10번 안에 정답을 맞춰보세요!")

# 게임 해볼까요
for i in range(1, 11):
    print(f"\n질문 {i}/10:")
    question = input("질문을 입력하세요: ")

    if question in answers:
        print(f"컴퓨터의 대답: {answers[question][answer]}")
    else:
        print("유효한 질문이 아닙니다. 참고 예시를 다시 확인하세요.")

    # 정답!! 땡? 딩동댕?
    guess = input("정답을 추측하시겠습니까? (예/아니오): ")
    if guess.lower() == "예":
        user_answer = input("생물, 비생물, 바이러스 중 하나를 입력하세요: ")
        if user_answer == answer:
            print("정답입니다! 게임을 종료합니다.")
            break
        else:
            print("틀렸습니다. 계속 진행합니다.")
else:
    print(f"게임 종료! 정답은 '{answer}'였습니다.")
# Out:
# 컴퓨터가 '생물', '비생물', '바이러스' 중 하나를 선택했습니다.
# 다음은 질문 예시입니다 (랜덤 순서):
# - 복제라는 개념을 적용할 수 있나요?
# - 자연계에서 발견되나요?
# - 관찰하기 위해 특수 도구가 필요한가요?
# - 스스로 빛을 발하나요?
# - 과학적 연구의 대상이 될 수 있나요?
# - 항상성 유지를 하나요?
# - 생식과 유전을 하나요?
# - 날씨를 예측할 수 있나요?
# - 다른 것과 상호작용을 하나요?
# - 기계를 조작할 수 있나요?
# - 발생과 성장을 하나요?
# - 인간이 타고 이동할 수 있나요?
# - 적응과 진화를 하나요?
# - 물질 대사를 하나요?
# - 특정 조건에서 활동을 멈출 수 있나요?
# - 자극과 반응을 하나요?
# - 사람이 직접 제어해야 하나요?
# - 스스로 도구를 만들 수 있나요?
# - 시간의 흐름에 따라 변화할 수 있나요?
# - 특정 에너지원이 필요하다고 볼 수 있나요?
# - 전기를 생산하나요?
# - 말을 할 수 있나요?
# - 인간에게 유익하거나 해로운 영향을 줄 수 있나요?
# - 운동 에너지를 생성하나요?
# - 빛에 의해 에너지를 변화시킬 수 있나요?
# - 핵을 가지고 있나요?
# - 음악을 들을 수 있나요?
# - 물과 상호작용을 하나요?
# - 온도 변화에 영향을 받나요?
# - 외부 환경에 따라 형태가 변할 수 있나요?
#
# 이 질문을 참고하여 10번 안에 정답을 맞춰보세요!
#
# 질문 1/10:
# 질문을 입력하세요: 발생과 성장을 하나요?
# 컴퓨터의 대답: 예
# 정답을 추측하시겠습니까? (예/아니오): 예
# 생물, 비생물, 바이러스 중 하나를 입력하세요: 생물
# 정답입니다! 게임을 종료합니다.
